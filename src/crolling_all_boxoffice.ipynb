# %%
import pandas as pd

# 파일을 열고 잘못된 문자를 무시하여 읽기
with open('/home/jieun/ws/Marvel/db.csv', 'r', encoding='utf-8', errors='ignore') as file:
    db_data = pd.read_csv(file, header=0)

db_data.head()
# Out:
#    Unnamed: 0                      Original Title Company  Rate  Metascore  \
# 0           1                            Iron Man  Marvel   7.9         79
# 1           2                 The Incredible Hulk  Marvel   6.7         61
# 2           3                          Iron Man 2  Marvel   7.0         57
# 3           4                                Thor  Marvel   7.0         57
# 4           5  Captain America: The First Avenger  Marvel   6.9         66
#
#    Minutes  Release     Budget  Opening Weekend USA   GrossUSA  \
# 0      126     2008  140000000             98618668  318604126
# 1      112     2008  150000000             55414050  134806913
# 2      124     2010  200000000            128122480  312433331
# 3      115     2011  150000000             65723338  181030624
# 4      124     2011  140000000             65058524  176654505
#
#    Gross Worldwide
# 0        585366247
# 1        263427551
# 2        623933331
# 3        449326618
# 4        370569774

# %%
db_data = db_data.drop('Unnamed: 0', axis=1)
db_data.head()
# Out:
#                        Original Title Company  Rate  Metascore  Minutes  \
# 0                            Iron Man  Marvel   7.9         79      126
# 1                 The Incredible Hulk  Marvel   6.7         61      112
# 2                          Iron Man 2  Marvel   7.0         57      124
# 3                                Thor  Marvel   7.0         57      115
# 4  Captain America: The First Avenger  Marvel   6.9         66      124
#
#    Release     Budget  Opening Weekend USA   GrossUSA  Gross Worldwide
# 0     2008  140000000             98618668  318604126        585366247
# 1     2008  150000000             55414050  134806913        263427551
# 2     2010  200000000            128122480  312433331        623933331
# 3     2011  150000000             65723338  181030624        449326618
# 4     2011  140000000             65058524  176654505        370569774

# %%
db_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Original Title       39 non-null     object
#  1   Company              39 non-null     object
#  2   Rate                 39 non-null     float64
#  3   Metascore            39 non-null     int64
#  4   Minutes              39 non-null     int64
#  5   Release              39 non-null     int64
#  6   Budget               39 non-null     int64
#  7   Opening Weekend USA  39 non-null     int64
#  8   GrossUSA             39 non-null     int64
#  9   Gross Worldwide      39 non-null     int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 3.2+ KB

# %%
db_data.tail()
# Out:
#     Original Title Company  Rate  Metascore  Minutes  Release     Budget  \
# 34    Wonder Woman      DC   7.4         76      141     2017  149000000
# 35  Justice League      DC   6.4         45      120     2017  300000000
# 36         Aquaman      DC   7.0         55      143     2018  160000000
# 37         Shazam!      DC   7.1         71      132     2019  100000000
# 38           Joker      DC   8.7         59      122     2019   55000000
#
#     Opening Weekend USA   GrossUSA  Gross Worldwide
# 34            103251471  412563408        821847012
# 35             93842239  229024295        657924295
# 36             67873522  335061807       1148161807
# 37             53505326  140371656        364571656
# 38             96202337  333204580       1060504580

# %%
db_data_temp = db_data.drop(range(22,39))
db_data_temp.tail()
# Out:
#             Original Title Company  Rate  Metascore  Minutes  Release  \
# 17           Black Panther  Marvel   7.3         88      134     2018
# 18  Avengers: Infinity War  Marvel   8.5         68      149     2018
# 19    Ant-Man and the Wasp  Marvel   7.1         70      118     2018
# 20           Captain Marve  Marvel   6.9         64      123     2019
# 21       Avengers: Endgame  Marvel   8.5         78      181     2019
#
#        Budget  Opening Weekend USA   GrossUSA  Gross Worldwide
# 17  200000000            202003951  700059566       1346913161
# 18  321000000            257698183  678815482       2048359754
# 19  162000000             75812205  216648740        622674139
# 20  175000000            153433423  426829839       1128274794
# 21  356000000            357115007  858373000       2797800564

# %%
db_data_temp
db_data_temp.tail()
# Out:
#             Original Title Company  Rate  Metascore  Minutes  Release  \
# 17           Black Panther  Marvel   7.3         88      134     2018
# 18  Avengers: Infinity War  Marvel   8.5         68      149     2018
# 19    Ant-Man and the Wasp  Marvel   7.1         70      118     2018
# 20           Captain Marve  Marvel   6.9         64      123     2019
# 21       Avengers: Endgame  Marvel   8.5         78      181     2019
#
#        Budget  Opening Weekend USA   GrossUSA  Gross Worldwide
# 17  200000000            202003951  700059566       1346913161
# 18  321000000            257698183  678815482       2048359754
# 19  162000000             75812205  216648740        622674139
# 20  175000000            153433423  426829839       1128274794
# 21  356000000            357115007  858373000       2797800564

# %%
import pandas as pd

# 파일을 열고 잘못된 문자를 무시하여 읽기
with open('/home/jieun/ws/eda/mcu_box_office.csv', 'r', encoding='utf-8', errors='ignore') as file:
    mcu_box_office = pd.read_csv(file, header=0)

mcu_box_office.head()
# Out:
#                        Original Title Company  Rate  Metascore  Minutes  \
# 0                            Iron Man  Marvel   7.9         79      126
# 1                 The Incredible Hulk  Marvel   6.7         61      112
# 2                          Iron Man 2  Marvel   7.0         57      124
# 3                                Thor  Marvel   7.0         57      115
# 4  Captain America: The First Avenger  Marvel   6.9         66      124
#
#    Release     Budget  Opening Weekend USA   GrossUSA  Gross Worldwide  \
# 0     2008  140000000             98618668  318604126        585366247
# 1     2008  150000000             55414050  134806913        263427551
# 2     2010  200000000            128122480  312433331        623933331
# 3     2011  150000000             65723338  181030624        449326618
# 4     2011  140000000             65058524  176654505        370569774
#
#   Release Date         Director  Run Time In Minutes
# ...

# %%
import pandas as pd

# 파일을 열고 잘못된 문자를 무시하여 읽기
with open('/home/jieun/ws/eda/mcu_box_office.csv', 'r', encoding='utf-8', errors='ignore') as file:
    data = pd.read_csv(file, header=0)

data.head()
# Out:
#                                 Movie Release Date  Domestic Box Office  \
# 0                            Iron Man     5/2/2008            318604126
# 1                 The Incredible Hulk    6/13/2008            134806913
# 2                          Iron Man 2     5/7/2010            312433331
# 3                                Thor     5/6/2011            181030624
# 4  Captain America: The First Avenger    7/22/2011            176654505
#
#    Inflation Adjusted Domestic  International Box Office  \
# 0                    467231126                 266567421
# 1                    197704288                 130766946
# 2                    416973763                 308723058
# 3                    240384926                 268295994
# 4                    234574020                 193915271
#
#    World Wide Box Office  Opening Weekend     Budget  IMDb Score  Meta Score  \
# 0              585171547        102118668  186000000         7.9          79
# ...

# %%
temp_li = []

for idx, row in db_data_temp.iterrows():
    # 'Original Title'과 'Movie'가 일치하는 영화의 'Release Date' 값 찾기
    release_date = data[data["Movie"] == row["Original Title"]]["Release Date"].values

    # 값을 리스트에 추가 (값이 여러 개일 경우 첫 번째 값만 추가하고 싶다면 [0]을 추가)
    if len(release_date) > 0:
        temp_li.append(release_date[0])  # 첫 번째 값을 추가
    else:
        temp_li.append(None)  # 일치하는 값이 없을 경우 None 추가

temp_li
# Out:
# ['5/2/2008',
#  '6/13/2008',
#  '5/7/2010',
#  '5/6/2011',
#  '7/22/2011',
#  '5/4/2012',
#  None,
#  '11/8/2013',
#  '4/4/2014',
#  None,
#  '5/1/2015',
#  '7/17/2015',
#  '5/6/2016',
#  '11/4/2016',
#  '5/5/2017',
#  '7/7/2017',
#  None,
#  '2/16/2018',
#  None,
#  '7/6/2018',
#  None,
#  '4/26/2019']

# %%
temp_li = []
s="Release Date"
for i, row in enumerate(data_temp["Original Title"]):
    # print(row["Original Title"], row["Original Title"] in mcu_box_office["Movie"])
    # print(row in mcu_box_office["Movie"])
    for j, mcu_row in enumerate(data["Movie"]):
        if row.lower() == mcu_row.lower():
            # print(i, j, row, data["Release Date"][j])
            temp_li.append(data[s][j])

print(len(temp_li))

data_temp["Release Date"] = temp_li
data_temp.head()
# Out:
# 22

# %%
temp_li = []
s="Run Time In Minutes"
for i, row in enumerate(data_temp["Original Title"]):
    # print(row["Original Title"], row["Original Title"] in mcu_box_office["Movie"])
    # print(row in mcu_box_office["Movie"])
    for j, mcu_row in enumerate(data["Movie"]):
        if row.lower() == mcu_row.lower():
            # print(i, j, row, data["Release Date"][j])
            temp_li.append(data[s][j])

print(len(temp_li))

data_temp["Run Time In Minutes"] = temp_li
data_temp.head()
# Out:
# 22
#                        Original Title Company  Rate  Metascore  Minutes  \
# 0                            Iron Man  Marvel   7.9         79      126
# 1                 The Incredible Hulk  Marvel   6.7         61      112
# 2                          Iron Man 2  Marvel   7.0         57      124
# 3                                Thor  Marvel   7.0         57      115
# 4  Captain America: The First Avenger  Marvel   6.9         66      124
#
#    Release     Budget  Opening Weekend USA   GrossUSA  Gross Worldwide  \
# 0     2008  140000000             98618668  318604126        585366247
# 1     2008  150000000             55414050  134806913        263427551
# 2     2010  200000000            128122480  312433331        623933331
# 3     2011  150000000             65723338  181030624        449326618
# 4     2011  140000000             65058524  176654505        370569774
#
#   Release Date         Director  Run Time In Minutes
# ...

# %%
data_temp.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 db_data_temp.tail()
#
# NameError: name 'db_data_temp' is not defined

# %%
temp_li = []

for idx, row in data_temp.iterrows():
    # 'Original Title'과 'Movie'가 일치하는 영화의 'Release Date' 값 찾기
    release_date = data[data["Movie"].str.lower() == row["Original Title"].lower()]["Release Date"].values
    
    #release_date = data[data["Movie"] == row["Original Title"]]["Release Date"].values

    # 값을 리스트에 추가 (값이 여러 개일 경우 첫 번째 값만 추가하고 싶다면 [0]을 추가)
    if len(release_date) > 0:
        temp_li.append(release_date[0])  # 첫 번째 값을 추가
    else:
        temp_li.append(None)  # 일치하는 값이 없을 경우 None 추가

temp_li

# %%
num_li = [6, 9, 10, 16, 18, 20]
for val in num_li:
    data_temp["Original Title"][val] = data["Movie"][val]
# Out:
# /tmp/ipykernel_10004/1937072469.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data_temp["Original Title"][val] = data["Movie"][val]
# /tmp/ipykernel_10004/1937072469.py:3: SettingWithCopyWarning:
# ...

# %%
data_temp.to_csv('/home/jieun/ws/eda/mcu_box_office1.csv', index=False)
